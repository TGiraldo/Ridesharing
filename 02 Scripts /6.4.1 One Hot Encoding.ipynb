# %%
import folium
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import os
import geopandas as gpd
from shapely.geometry import Point

# %%
path =r'/Users/thaliagiraldo/Library/Mobile Documents/com~apple~CloudDocs/CareerFoundry/Immersion /Lesson 6'

# %%
df = pd.read_csv(os.path.join(path, 'df_cleaned_Jan27.csv'), index_col = False)

# %%
df
# Out:
#         Unnamed: 0           ride_id  rideable_type           started_at  \
# 0                0  4EAD8F1AD547356B  electric_bike  2023-11-30 21:50:00
# 1                1  6322270563BF5470  electric_bike  2023-11-03 09:44:00
# 2                2  B37BDE091ECA38E0  electric_bike  2023-11-30 11:39:00
# 3                3  CF0CA5DD26E4F90E   classic_bike  2023-11-08 10:01:00
# 4                4  EB8381AA641348DB   classic_bike  2023-11-03 16:20:00
# ...            ...               ...            ...                  ...
# 362459      362459  30B44BD4C16E688C   classic_bike  2023-11-24 08:39:00
# 362460      362460  094A79892812BAB9   classic_bike  2023-11-06 09:07:00
# 362461      362461  F0A7DF8A44FDA3CB  electric_bike  2023-11-10 19:35:00
# 362462      362462  4D5E3685BB913A3C   classic_bike  2023-11-27 09:11:00
# 362463      362463  1FA95C375BE4B6A6  electric_bike  2023-11-20 16:16:00
#
#                    ended_at          start_station_name start_station_id  \
# ...

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
#1 is electric bike 
#0 is classic bike
dummies_rideable = pd.get_dummies(df.rideable_type).astype(int)

# %%
merged_dummies_rideable = pd.concat([df,dummies_rideable], axis = 'columns')

# %%
merged_dummies_rideable = merged_dummies_rideable.drop(columns = ['rideable_type_code'])

# %%
merged_dummies_rideable.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'trip_duration', 'trip_distance_miles',
#        'trip_date_start', 'trip_date_end', 'start_time', 'end_time',
#        'ride_day_of_week', 'ride_day_of_week_numeric', 'hour_start_time',
#        'time_of_day', 'classic_bike', 'electric_bike'],
#       dtype='object')

# %%
dummies_member = pd.get_dummies(merged_dummies_rideable.member_casual).astype(int)

# %%
dummies_member
# Out:
#         casual  member
# 0            0       1
# 1            0       1
# 2            0       1
# 3            0       1
# 4            0       1
# ...        ...     ...
# 362459       0       1
# 362460       0       1
# 362461       0       1
# 362462       0       1
# 362463       0       1
#
# [362464 rows x 2 columns]

# %%
merged = pd.concat([merged_dummies_rideable,dummies_member], axis = 'columns')
merged
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       4EAD8F1AD547356B  electric_bike  2023-11-30 21:50:00
# 1       6322270563BF5470  electric_bike  2023-11-03 09:44:00
# 2       B37BDE091ECA38E0  electric_bike  2023-11-30 11:39:00
# 3       CF0CA5DD26E4F90E   classic_bike  2023-11-08 10:01:00
# 4       EB8381AA641348DB   classic_bike  2023-11-03 16:20:00
# ...                  ...            ...                  ...
# 362459  30B44BD4C16E688C   classic_bike  2023-11-24 08:39:00
# 362460  094A79892812BAB9   classic_bike  2023-11-06 09:07:00
# 362461  F0A7DF8A44FDA3CB  electric_bike  2023-11-10 19:35:00
# 362462  4D5E3685BB913A3C   classic_bike  2023-11-27 09:11:00
# 362463  1FA95C375BE4B6A6  electric_bike  2023-11-20 16:16:00
#
#                    ended_at          start_station_name start_station_id  \
# 0       2023-11-30 22:13:00             Millennium Park            13008
# 1       2023-11-03 10:17:00      Broadway & Sheridan Rd            13323
# ...

# %%
merged.to_csv(os.path.join(path, 'OHE_cleaned_Feb1.csv'))
